# %%
#Importing the needed libraries and functions.
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
#Importing the Dataset
url = '/Users/amirrezakamkar/Desktop/Works_in_progress/Ironhack/7_7th_week/Project/machine-learning-project/data/clean/clean_dataset_df.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   airline_name flight_code departure_city arrival_city  flight_duration  \
# 0     SpiceJet     SG-8709          Delhi       Mumbai              130
# 1     SpiceJet     SG-8157          Delhi       Mumbai              140
# 2     Air Asia      I5-764          Delhi       Mumbai              130
# 3      Vistara      UK-995          Delhi       Mumbai              135
# 4      Vistara      UK-963          Delhi       Mumbai              140
#
#    stops  price    class  days_left departure_time_group arrival_time_group
# 0      0   5953  Economy          1              Evening              Night
# 1      0   5953  Economy          1        Early Morning            Morning
# 2      0   5956  Economy          1        Early Morning      Early Morning
# 3      0   5955  Economy          1              Morning          Afternoon
# 4      0   5955  Economy          1              Morning            Morning

# %%
#Removing the irrelevant columns.
df = df.drop(columns = 'flight_code')

# %%
#Converting the categorical columns into boolean.
df2 = pd.get_dummies(df, columns=['airline_name', 'departure_city', 'arrival_city', 'departure_time_group', 'arrival_time_group'])

# %%
#Spliting the dataset into two sub-dataset, one for economy class and one for business calss.
df_economy = df2[df2['class'] == 'Economy'].reset_index(drop=True)
df_business = df2[df2['class'] == 'Business'].reset_index(drop=True)

# %%
df_economy.head()
# Out:
#    flight_duration  stops  price    class  days_left  airline_name_Air Asia  \
# 0              130      0   5953  Economy          1                  False
# 1              140      0   5953  Economy          1                  False
# 2              130      0   5956  Economy          1                   True
# 3              135      0   5955  Economy          1                  False
# 4              140      0   5955  Economy          1                  False
#
#    airline_name_Air India  airline_name_Go First  airline_name_Indigo  \
# 0                   False                  False                False
# 1                   False                  False                False
# 2                   False                  False                False
# 3                   False                  False                False
# 4                   False                  False                False
#
#    airline_name_SpiceJet  ...  departure_time_group_Evening  \
# 0                   True  ...                          True
# 1                   True  ...                         False
# 2                  False  ...                         False
# 3                  False  ...                         False
# 4                  False  ...                         False
#
#    departure_time_group_Late Night  departure_time_group_Morning  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                          True
# 4                            False                          True
#
#    departure_time_group_Night  arrival_time_group_Afternoon  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                          True
# 4                       False                         False
#
#    arrival_time_group_Early Morning  arrival_time_group_Evening  \
# 0                             False                       False
# 1                             False                       False
# 2                              True                       False
# 3                             False                       False
# 4                             False                       False
#
#    arrival_time_group_Late Night  arrival_time_group_Morning  \
# 0                          False                       False
# 1                          False                        True
# 2                          False                       False
# 3                          False                       False
# 4                          False                        True
#
#    arrival_time_group_Night
# 0                      True
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 35 columns]

# %%
#converting boolean columns into integer (0,1)
bool_cols = df_economy.select_dtypes(include=['bool']).columns  # Select boolean columns
df_economy[bool_cols] = df_economy[bool_cols].astype(int) 
df_economy = df_economy.drop(columns= 'class')

# %%
#Selecting features and target columns
features_e = df_economy.drop(columns ='price')
target_e = df_economy['price']

# %%
#Spliting the dataset into two groups, one for training and one for test
X_train, X_test, y_train, y_test = train_test_split(features_e, target_e, test_size = 0.20, random_state=0)

# %%
#Normalizing the numerical columns using MinMaxScaler
normalizer = MinMaxScaler()

normalizer.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_norm = normalizer.transform(X_train)

X_test_norm = normalizer.transform(X_test)

# %%
#Converting the numpy arrays into Pandas dataframes.
X_train_norm = pd.DataFrame(X_train_norm, columns = X_train.columns)
X_test_norm = pd.DataFrame(X_test_norm, columns = X_test.columns)

# %%
#Using AdaBoost model for prediction.
ada_reg = AdaBoostRegressor(DecisionTreeRegressor(max_depth=20),
                            n_estimators=100)

# %%
ada_reg.fit(X_train_norm, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),
#                   n_estimators=100)

# %%
#Evaluation the performance.
pred = ada_reg.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", ada_reg.score(X_test_norm, y_test))
# Out:
# MAE 893.4615048728755
# RMSE 1528.1726770951493
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# R2 score 0.8330645728894952

# %%
# The whole above process will be done for the business class:

# %%
bool_cols = df_economy.select_dtypes(include=['bool']).columns  # Select boolean columns
df_business[bool_cols] = df_business[bool_cols].astype(int) 
df_business = df_business.drop(columns= 'class')

# %%
features_b = df_business.drop(columns ='price')
target_b = df_business['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(features_b, target_b, test_size = 0.20, random_state=0)

# %%
normalizer = MinMaxScaler()

normalizer.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_norm = normalizer.transform(X_train)

X_test_norm = normalizer.transform(X_test)

# %%
X_train_norm = pd.DataFrame(X_train_norm, columns = X_train.columns)
X_test_norm = pd.DataFrame(X_test_norm, columns = X_test.columns)

# %%
ada_reg = AdaBoostRegressor(DecisionTreeRegressor(max_depth=20),
                            n_estimators=100)

# %%
ada_reg.fit(X_train_norm, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),
#                   n_estimators=100)

# %%
pred = ada_reg.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", ada_reg.score(X_test_norm, y_test))
# Out:
# MAE 2815.9753815543936
# RMSE 4963.25828011397
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# R2 score 0.853140059343147
